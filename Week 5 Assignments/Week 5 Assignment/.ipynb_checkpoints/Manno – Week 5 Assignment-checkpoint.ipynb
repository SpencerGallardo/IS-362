# %% [markdown]
# # IS 362 – Week 5 Assignment
#
# ## Your task in this week’s assignment is to answer three questions:
#     1. What is the northernmost airport in the United States?
#     2. What is the easternmost airport in the United States?
#     3. On February 12th, 2013, which New York area airport had the windiest weather?

# %%
import pandas as pd
#set some pandas options controling output format
pd.set_option('display.notebook_repr_html',True) # output as flat text and not HTML
pd.set_option('display.max_rows',6) # this is the maximum number of rows we will display

# %%
# read the csv into a dataframe
airports = pd.read_csv('data/airports.csv')

# %%
# Display the columns in the dataframe, and get a peak at how it's formatted
airports.head()
# Out:
#    faa                           name        lat        lon   alt   tz dst  \
# 0  04G              Lansdowne Airport  41.130472 -80.619583  1044 -5.0   A
# 1  06A  Moton Field Municipal Airport  32.460572 -85.680028   264 -6.0   A
# 2  06C            Schaumburg Regional  41.989341 -88.101243   801 -6.0   A
# 3  06N                Randall Airport  41.431912 -74.391561   523 -5.0   A
# 4  09J          Jekyll Island Airport  31.074472 -81.427778    11 -5.0   A
#
#               tzone
# 0  America/New_York
# 1   America/Chicago
# 2   America/Chicago
# 3  America/New_York
# 4  America/New_York

# %%
# sort the list by latitude in descending order. This will display the airports with
# the highest latitude first.
airports.sort_values(['lat'], ascending=[False])
# Out:
#      faa                        name        lat         lon   alt    tz dst  \
# 417  EEN     Dillant Hopkins Airport  72.270833   42.898333   149  -5.0   A
# 230  BRW  Wiley Post Will Rogers Mem  71.285446 -156.766003    44  -9.0   A
# 110  AIN          Wainwright Airport  70.638056 -159.994722    41  -9.0   A
# ..   ...                         ...        ...         ...   ...   ...  ..
# 231  BSF                Bradshaw Aaf  19.760056 -155.553717  6190 -10.0   A
# 734  KOA        Kona Intl At Keahole  19.738767 -156.045631    47 -10.0   N
# 679  ITO                   Hilo Intl  19.721375 -155.048469    38 -10.0   N
#
#                  tzone
# 417                 \N
# 230  America/Anchorage
# 110  America/Anchorage
# ..                 ...
# 231   Pacific/Honolulu
# 734   Pacific/Honolulu
# 679   Pacific/Honolulu
#
# [1458 rows x 8 columns]

# %% [markdown]
# ## Question 1 Answer
# Cross referencing our results with google maps it appears that our top result, Dillant Hopkins Airport, is in New Hampshire. It appears this field is incorrect.
#
# ![Airports.png](attachment:Airports.png)
#
# Our second result, Wiley Post-Will Rogers Memorial Airport, appears to be the correct result.

# %%
# sort the list by latitude in descending order. This will display the airports with
# the highest latitude first.
pd.set_option('display.max_rows',10) # this is the maximum number of rows we will display
airports.sort_values(['tz','lon'], ascending=[False, False])
# Out:
#      faa                           name        lat         lon   alt    tz  \
# 942  MYF               Montgomery Field  32.475900  117.759000    17   8.0
# 396  DVT  Deer Valley Municipal Airport  33.411700  112.457000  1478   8.0
# 417  EEN        Dillant Hopkins Airport  72.270833   42.898333   149  -5.0
# 444  EPM     Eastport Municipal Airport  44.910111  -67.012694    45  -5.0
# 624  HUL                   Houlton Intl  46.123083  -67.792056   489  -5.0
# ..   ...                            ...        ...         ...   ...   ...
# 600  HNL                  Honolulu Intl  21.318681 -157.922428    13 -10.0
# 587  HHI                    Wheeler Aaf  21.483500 -158.039667   837 -10.0
# 580  HDH                     Dillingham  21.579475 -158.197281    14 -10.0
# 794  LIH                          Lihue  21.975983 -159.338958   153 -10.0
# 207  BKH             Barking Sands Pmrf  22.022833 -159.785000    23 -10.0
#
#     dst             tzone
# 942   A    Asia/Chongqing
# 396   A    Asia/Chongqing
# 417   A                \N
# 444   A  America/New_York
# 624   A  America/New_York
# ..   ..               ...
# 600   N  Pacific/Honolulu
# 587   A  Pacific/Honolulu
# 580   A  Pacific/Honolulu
# 794   N  Pacific/Honolulu
# 207   A  Pacific/Honolulu
#
# [1458 rows x 8 columns]

# %% [markdown]
# # Question 2 Answer
# Cross referencing our results with google maps it appears that our top 3 reulsts are incorrect. The first two are in the wrong timezone, and as we know from the previous search Dillant Hopkins Airport is in New Hampshire. It appears that the 4th result, Eastport Municipal Airport, is the correct answer.
#
# ![Eastport.png](attachment:Eastport.png)

# %%
# read the csv into a dataframe
weather = pd.read_csv('data/weather.csv')

# %%
# Display the columns in the dataframe, and get a peak at how it's formatted
weather.head()
# Out:
#   origin  year  month  day  hour   temp   dewp  humid  wind_dir  wind_speed  \
# 0    EWR  2013      1    1     0  37.04  21.92  53.97     230.0    10.35702
# 1    EWR  2013      1    1     1  37.04  21.92  53.97     230.0    13.80936
# 2    EWR  2013      1    1     2  37.94  21.92  52.09     230.0    12.65858
# 3    EWR  2013      1    1     3  37.94  23.00  54.51     230.0    13.80936
# 4    EWR  2013      1    1     4  37.94  24.08  57.04     240.0    14.96014
#
#    wind_gust  precip  pressure  visib             time_hour
# 0  11.918651     0.0    1013.9   10.0  2013-01-01T00:00:00Z
# 1  15.891535     0.0    1013.0   10.0  2013-01-01T01:00:00Z
# 2  14.567241     0.0    1012.6   10.0  2013-01-01T02:00:00Z
# 3  15.891535     0.0    1012.7   10.0  2013-01-01T03:00:00Z
# 4  17.215830     0.0    1012.8   10.0  2013-01-01T04:00:00Z

# %%
# Filter out the correct year, month and day.
# Then sort the dataframe by wind_speed
# Using this it would appear that EWR had the windiest weather on 12Feb13. However the windspeed on that
# day appears to be incorrect. 
weather[((weather.year == 2013) & (weather.month == 2)) & (weather.day == 12)].sort_values('wind_speed', ascending = False)
# Out:
#       origin  year  month  day  hour   temp   dewp   humid  wind_dir  \
# 1015     EWR  2013      2   12     8  39.02  26.96   61.63     260.0
# 18433    LGA  2013      2   12     7  42.98  26.06   50.94     290.0
# 1024     EWR  2013      2   12    17  44.06  26.06   48.87     270.0
# 18444    LGA  2013      2   12    18  44.06  23.00   43.02     300.0
# 9728     JFK  2013      2   12    13  42.08  24.08   48.56     280.0
# ...      ...   ...    ...  ...   ...    ...    ...     ...       ...
# 18427    LGA  2013      2   12     1  42.98  41.00   92.65       NaN
# 9715     JFK  2013      2   12     0  42.80  42.80  100.00       0.0
# 9716     JFK  2013      2   12     1  42.80  42.80  100.00       0.0
# 9717     JFK  2013      2   12     2  44.60  42.80   93.35       0.0
# 1007     EWR  2013      2   12     0  42.98  42.98  100.00       0.0
#
#        wind_speed    wind_gust  precip  pressure  visib             time_hour
# 1015   1048.36058  1206.432388     0.0    1008.3  10.00  2013-02-12T08:00:00Z
# 18433    23.01560    26.485892     0.0    1007.1  10.00  2013-02-12T07:00:00Z
# 1024     21.86482    25.161598     0.0    1012.5  10.00  2013-02-12T17:00:00Z
# 18444    21.86482    25.161598     0.0    1011.7  10.00  2013-02-12T18:00:00Z
# 9728     20.71404    23.837303     0.0    1011.6  10.00  2013-02-12T13:00:00Z
# ...           ...          ...     ...       ...    ...                   ...
# 18427     3.45234     3.972884     0.0    1004.6   2.50  2013-02-12T01:00:00Z
# 9715      0.00000     0.000000     0.0       NaN   0.12  2013-02-12T00:00:00Z
# 9716      0.00000     0.000000     0.0       NaN   0.12  2013-02-12T01:00:00Z
# 9717      0.00000     0.000000     0.0       NaN   0.12  2013-02-12T02:00:00Z
# 1007      0.00000     0.000000     0.0    1004.7   0.50  2013-02-12T00:00:00Z
#
# [72 rows x 15 columns]

# %%
# Filter out the correct year, month and day. Also filter out incorrect windspeeds I used 350 because 
# 301 ± 20 mph were the highest winds ever recorded on earth (https://en.wikipedia.org/wiki/Tornado_records)
# I Then sort the dataframe by wind_speed
# Using this it would appear that LGA had the windiest weather on 12Feb13. However the this dataset is broken
# down by hour.
weather[((weather.year == 2013) & (weather.month == 2)) & (weather.day == 12) & (weather.wind_speed < 350)].sort_values('wind_speed', ascending = False)
# Out:
#       origin  year  month  day  hour   temp   dewp   humid  wind_dir  \
# 18433    LGA  2013      2   12     7  42.98  26.06   50.94     290.0
# 1024     EWR  2013      2   12    17  44.06  26.06   48.87     270.0
# 18444    LGA  2013      2   12    18  44.06  23.00   43.02     300.0
# 1014     EWR  2013      2   12     7  39.92  28.04   62.21     270.0
# 9728     JFK  2013      2   12    13  42.08  24.08   48.56     280.0
# ...      ...   ...    ...  ...   ...    ...    ...     ...       ...
# 18427    LGA  2013      2   12     1  42.98  41.00   92.65       NaN
# 9715     JFK  2013      2   12     0  42.80  42.80  100.00       0.0
# 9716     JFK  2013      2   12     1  42.80  42.80  100.00       0.0
# 9717     JFK  2013      2   12     2  44.60  42.80   93.35       0.0
# 1007     EWR  2013      2   12     0  42.98  42.98  100.00       0.0
#
#        wind_speed  wind_gust  precip  pressure  visib             time_hour
# 18433    23.01560  26.485892     0.0    1007.1  10.00  2013-02-12T07:00:00Z
# 1024     21.86482  25.161598     0.0    1012.5  10.00  2013-02-12T17:00:00Z
# 18444    21.86482  25.161598     0.0    1011.7  10.00  2013-02-12T18:00:00Z
# 1014     20.71404  23.837303     0.0    1007.8  10.00  2013-02-12T07:00:00Z
# 9728     20.71404  23.837303     0.0    1011.6  10.00  2013-02-12T13:00:00Z
# ...           ...        ...     ...       ...    ...                   ...
# 18427     3.45234   3.972884     0.0    1004.6   2.50  2013-02-12T01:00:00Z
# 9715      0.00000   0.000000     0.0       NaN   0.12  2013-02-12T00:00:00Z
# 9716      0.00000   0.000000     0.0       NaN   0.12  2013-02-12T01:00:00Z
# 9717      0.00000   0.000000     0.0       NaN   0.12  2013-02-12T02:00:00Z
# 1007      0.00000   0.000000     0.0    1004.7   0.50  2013-02-12T00:00:00Z
#
# [71 rows x 15 columns]

# %%
# To account for the fact that the wind data is taken every hour I will take the average hourly 
# windspeed for each airport that day.
weather[((weather.year == 2013) & (weather.month == 2)) & (weather.day == 12) & (weather.wind_speed < 350)].groupby('origin').wind_speed.mean()
# Out:
# origin
# EWR    12.508478
# JFK    13.090123
# LGA    13.857309
# Name: wind_speed, dtype: float64

# %% [markdown]
# # Question 3 Answer
# With an average windspeed of 13.857309 it appears that LGA had the windiest weather February 12th, 2013.

# %% [markdown]
# ## In Summary:
#     1. What is the northernmost airport in the United States?
#             Wiley Post-Will Rogers Memorial Airport
#     2. What is the easternmost airport in the United States?
#             Eastport Municipal Airport
#     3. On February 12th, 2013, which New York area airport had the windiest weather?
#             Laguardia Airport
