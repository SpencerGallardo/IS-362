# %% [markdown]
# # Matthew Manno
# # is360 Final Project
#
# I made this notebook to help me with a project that I have at work. I am a construction scheduler and I work with a program that stores information about projects in a relational database. The program allows you to import information about a schedule into it using Microsoft Excel files. The two types of information I am interested in importing into the program are:
#
# 1. __Activity/Task Information :__ Activity information contains general information about the main constituents of a project, the activities/tasks. Each activity describes a portion of work on a project. The columns that make up an activity are:
#
#     1. __ID :__ This is a unique alpha numeric identifier for an activity
#
#     2. __Status :__ This tells the program the current activity's status. If it has started, or if it has completed. All of the activities we will be making will have a status of "Not Started". This field is basically worthless, but the program requieres it when you are importing an activitiy.
#
#     3. __WBS :__ The wbs code is a code that tells the program where to place the activity in the project's WBS hierachy. All activities will be imported into the same location in the WBS hiearchy. This field is basically worthless, but the program requieres it when you are importing an activitiy.
#
#     4. __act_name :__ This field is a human readable field that contains (2)two pieces of information.<BR>    1: "prefix" consisting of a description of the work represented by the actvity. ie: "Erect Masonry Walls"<BR>    2: A "suffix" consisting of where the work will be performed. ie: " @ 3rd Floor"
#
#     5. __duration :__ This is an integer it represents how many days an activity will take.
#
#     6. __start :__ This field tells us when the activity will eventually _start_, based on information I recieved from my client. As this project is currently underway, not all activities will have a start date.
#
#     7. __finish :__ This field tells us when the activity will eventually _finish_, based on information I recieved from my client. As this project is currently underway, not all activities will have a finish date.
#
#     8. __floor_id :__ This field corresponds with another table in the database that tells us what floor the activity is on. ie: the 4th floor. This field is imported to the program as a string. Because not all floors are nummeric or even floors. For instance "Function Room 1" This "floor" has a code of FR1.<BR><BR>
# 2. __Relationship/Logic Information :__ Relationship information consists of the realationship / logic information of a project. I will go into detail on this information below.

# %%
# Import numpy
import numpy as np
# Import Pandas
import pandas as pd
# import the requests library to send http requests to the NYT API
import requests
# import json library for parsing JSON and converting JSON to python dictionaries
import json as json

#set some pandas options controling output format
pd.set_option('display.notebook_repr_html',True) # output as flat text and not HTML
pd.set_option('display.max_rows', None) # this is the maximum number of rows we will display
pd.set_option('display.max_columns', None) # this is the maximum number of rows we will display

# %%
# There are two types of activities that we can create with this notebook. One are activities 
# that we have start and finish data for, and ones that we do not. strStandardActivities will hold
# the file string for activities which we do not have dates for.
strStandardActivities = 'input/Import_Activities-Standard_Floors.csv'

# strSourceActivities holds the file string for activities for activities that we do have dates for.
strSourceActivities = 'input/Import_5Beek_Amen-Activities.csv'
# strSourceLogic contains a template for our activity logic. This will allow us to create logic 
# quickly for every activity on a floor.
strSourceLogic = 'input/Import_5Beek_Amen-Logic.csv'

# This is the file we will output our activity information to.
strActivityFileOutput = 'output/Export_Activities_From_Pandas.csv'
# This is the file we will output our logic information to.
strLogicFileOutput = 'output/Export_Logic_From_Pandas.csv'

# the string to cache the WBS code for activities we are adding. They will all have the same WBS code
strWBSCode = 'BH.BL-4.115 Nassau1.Floors.4'
# the string to cache the activity status information. All activities will be "Not Started".
strStatus = 'Not Started'

# %%
# this function takes a template of activities and duplicates them the specified number of times.
# intStart: represents the floor to start creating activities for.
# intFinish: represents the floor to stop creating activities for.
def setActivitiesFromTemplate(intStart, intFinish):
    # import the template for the activities we will be basing the schedule off of.
    dfNew = pd.read_csv(strStandardActivities,dtype={'ID': str})
    # declare the dataframe that will hold our tasks.
    dfNewTasks = pd.DataFrame(columns=['id', 'status', 'wbs', 'act_name', 'duration', 'floor_id'])

    # Within the loop below we are formatting the activity information for importing.
    #    id: has 3 parts:
    #         1. Starts with the string "NA." 
    #         2. The current loop's integer as a 2 digit number with preceeding zeroes. 
    #            This represents the floor the activity is on.
    #         3. Ends with the ID code for the current activity as a 3 digit number with
    #            preceeding zeroes. This represents the activities unique ID.
    #            For example:
    #        "NA." + "02" + "990" => NA.10990
    #     act_name: holds the activity description is consists of the activity description
    #     the string " @ Floor " and the integer of the floor it's on cast as a string.
    #     For example:
    #        "Build CMU Walls" + " @ Floor " + 2 => "Build CMU Walls @ Floor 2"
    
    # for the range the user stipulated...
    for i in range(intStart, intFinish):
        # cache the new dataframe with the new string formatting
        dfCache = pd.DataFrame({
            'id' : 'NA.' + str(i).zfill(2) + dfNew['ID'].str.zfill(3), \
            'status' : strStatus, \
            'wbs' : strWBSCode, \
            'act_name' : dfNew['Name'] + ' @ Floor ' + str(i), \
            'duration' : dfNew['Duration'], \
            'floor_id' : str(i).zfill(2)})
        
        # combine the new dataframe with the exiting one.
        dfNewTasks = pd.DataFrame(pd.concat([dfNewTasks, dfCache]))
                
    # reset the index of the new dataframe
    dfNewTasks.reset_index(inplace=True, drop=True) 
    
    # Reorder the columns to make import easier.
    dfNewTasks = dfNewTasks[['id', 'status', 'wbs', 'act_name', 'duration', 'floor_id']]

    # Return the formatted activity dataframe.
    return dfNewTasks

# %%
# This portion of the notebook is for activities that we have "start" and "finish" dates 
# supplied by the client. Not all activities will have start or finish dates.
# import our activity source file
dfSource = pd.read_csv(strSourceActivities,dtype={'ID': str, 'FloorID' : str})
# format the ID string to be 3 characters long with leading zeroes
dfSource['ID'] = dfSource['ID'].str.zfill(3)
# format the FloorID string to be 2 characters long with leading zeroes
dfSource['FloorID'] = dfSource['FloorID'].str.zfill(2)
# preview the dataframe
dfSource.head(1)
# Out:
#     ID                           Name  Duration   AS   AF FloorID
# 0  290  Final Paint @ Function Room 1         4  NaN  NaN     FR1

# %%
# create a new dataframe that contains our activity data for export formatted correctly
# This is simmilar to the formatting outlined in the setActivitiesFromTemplate function.
dfActivities = pd.DataFrame({
    'id' : 'NA.' + dfSource['FloorID'] + dfSource['ID'], \
    'status' : strStatus, 'wbs' : strWBSCode, \
    'act_name' : dfSource['Name'], 'duration' : dfSource['Duration'], \
    'start' : dfSource['AS'], 'finish' : dfSource['AF'], \
    'floor_id' : dfSource['FloorID']})
# preview the dataframe
dfActivities.head(1)
# Out:
#                         act_name  duration finish floor_id         id start  \
# 0  Final Paint @ Function Room 1         4    NaN      FR1  NA.FR1290   NaN
#
#         status                           wbs
# 0  Not Started  BH.BL-4.115 Nassau1.Floors.4

# %%
# Reorder the columns to make import easier.
dfActivities = dfActivities[['id', 'status', 'wbs', 'act_name', 'duration', 'start', 'finish', 'floor_id']]
# sort the dataframe by 'id'
dfActivities.sort_values('id', inplace=True)
# export the dataframe, without the index
dfActivities.to_csv(strActivityFileOutput, index=False)
# Review the dataframe we created.
dfActivities
# Out:
#             id       status                           wbs  \
# 15   NA.FR1010  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 5    NA.FR1012  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 2    NA.FR1017  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 19   NA.FR1020  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 21   NA.FR1030  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 22   NA.FR1040  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 20   NA.FR1060  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 3    NA.FR1070  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 1    NA.FR1100  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 17   NA.FR1120  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 10   NA.FR1130  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 14   NA.FR1140  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 13   NA.FR1150  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 6    NA.FR1160  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 9    NA.FR1170  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 7    NA.FR1173  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 8    NA.FR1230  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 4    NA.FR1250  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 11   NA.FR1257  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 12   NA.FR1262  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 16   NA.FR1280  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 0    NA.FR1290  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 18   NA.FR1300  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 38   NA.FR2010  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 28   NA.FR2012  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 25   NA.FR2017  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 42   NA.FR2020  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 44   NA.FR2030  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 45   NA.FR2040  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 43   NA.FR2060  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 26   NA.FR2070  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 24   NA.FR2100  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 40   NA.FR2120  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 33   NA.FR2130  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 37   NA.FR2140  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 36   NA.FR2150  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 29   NA.FR2160  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 32   NA.FR2170  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 30   NA.FR2173  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 31   NA.FR2230  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 27   NA.FR2250  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 34   NA.FR2257  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 35   NA.FR2262  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 39   NA.FR2280  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 23   NA.FR2290  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 41   NA.FR2300  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 63   NA.LNG010  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 49   NA.LNG017  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 68   NA.LNG020  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 69   NA.LNG050  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 50   NA.LNG070  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 61   NA.LNG080  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 66   NA.LNG090  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 47   NA.LNG100  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 71   NA.LNG110  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 65   NA.LNG120  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 48   NA.LNG123  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 59   NA.LNG130  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 62   NA.LNG140  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 60   NA.LNG150  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 56   NA.LNG160  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 58   NA.LNG170  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 57   NA.LNG173  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 72   NA.LNG177  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 53   NA.LNG185  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 52   NA.LNG250  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 51   NA.LNG253  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 70   NA.LNG257  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 55   NA.LNG260  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 54   NA.LNG270  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 64   NA.LNG280  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 46   NA.LNG290  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 67   NA.LNG300  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 88   NA.PFS010  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 78   NA.PFS012  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 75   NA.PFS017  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 92   NA.PFS020  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 94   NA.PFS030  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 95   NA.PFS040  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 96   NA.PFS050  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 93   NA.PFS060  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 76   NA.PFS070  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 74   NA.PFS100  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 90   NA.PFS120  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 83   NA.PFS130  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 87   NA.PFS140  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 86   NA.PFS150  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 79   NA.PFS160  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 82   NA.PFS170  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 80   NA.PFS173  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 81   NA.PFS230  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 77   NA.PFS250  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 84   NA.PFS257  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 85   NA.PFS262  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 89   NA.PFS280  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 73   NA.PFS290  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 91   NA.PFS300  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 113   NA.PR010  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 100   NA.PR017  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 118   NA.PR020  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 120   NA.PR030  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 121   NA.PR040  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 122   NA.PR050  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 119   NA.PR060  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 101   NA.PR070  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 111   NA.PR080  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 116   NA.PR090  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 98    NA.PR100  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 123   NA.PR110  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 115   NA.PR120  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 99    NA.PR123  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 109   NA.PR130  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 112   NA.PR140  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 110   NA.PR150  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 105   NA.PR160  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 108   NA.PR170  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 106   NA.PR173  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 103   NA.PR185  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 107   NA.PR230  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 102   NA.PR250  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 104   NA.PR270  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 114   NA.PR280  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 97    NA.PR290  Not Started  BH.BL-4.115 Nassau1.Floors.4
# 117   NA.PR300  Not Started  BH.BL-4.115 Nassau1.Floors.4
#
#                                               act_name  duration      start  \
# 15                Layout & Top Track @ Function Room 1         5   4-Apr-16
# 5                  Install CMU Walls @ Function Room 1        15   9-May-16
# 2    Frame & Core Board Risers/Stairs/Elevators @ F...        10   2-May-16
# 19                   Rough Duct Work @ Function Room 1        10   6-Apr-16
# 21           Rough Mechanical Piping @ Function Room 1        10   6-Apr-16
# 22                    Rough Plumbing @ Function Room 1        10   6-Apr-16
# 20           Rough Electrical/FA/BMS @ Function Room 1        10   7-Apr-16
# 3             Frame Walls & Ceilings @ Function Room 1        10        NaN
# 1         Firestopping & Inspections @ Function Room 1         5  28-Apr-16
# 17                       Prime Paint @ Function Room 1         5        NaN
# 10       Install Mechanical Finishes @ Function Room 1         2        NaN
# 14           Install Sprinkler Heads @ Function Room 1         4        NaN
# 13         Install Plumbing Finishes @ Function Room 1         2        NaN
# 6        Install Electrical Finishes @ Function Room 1         5        NaN
# 9                   Install Lighting @ Function Room 1         4        NaN
# 7                 Install FA Devices @ Function Room 1         5        NaN
# 8                   Install Flooring @ Function Room 1         6        NaN
# 4    Install Architectural Finishes & Trim  @ Funct...        10        NaN
# 11                  Install Millwork @ Function Room 1        15        NaN
# 12        Install Movable Partitions @ Function Room 1         5        NaN
# 16   Perform Plumbing & Sprinkler Finish Inspection...         1        NaN
# 0                        Final Paint @ Function Room 1         4        NaN
# 18                        Punchlist  @ Function Room 1         5   6-Apr-16
# 38                Layout & Top Track @ Function Room 2         5   8-Apr-16
# 28                 Install CMU Walls @ Function Room 2        15        NaN
# 25   Frame & Core Board Risers/Stairs/Elevators @ F...        10        NaN
# 42                   Rough Duct Work @ Function Room 2        10   8-Apr-16
# 44           Rough Mechanical Piping @ Function Room 2        10  11-Apr-16
# 45                    Rough Plumbing @ Function Room 2        10  21-Apr-16
# 43           Rough Electrical/FA/BMS @ Function Room 2        10   2-May-16
# 26            Frame Walls & Ceilings @ Function Room 2        10        NaN
# 24        Firestopping & Inspections @ Function Room 2         5   4-May-16
# 40                       Prime Paint @ Function Room 2         5        NaN
# 33       Install Mechanical Finishes @ Function Room 2         2        NaN
# 37           Install Sprinkler Heads @ Function Room 2         4        NaN
# 36         Install Plumbing Finishes @ Function Room 2         2        NaN
# 29       Install Electrical Finishes @ Function Room 2         5        NaN
# 32                  Install Lighting @ Function Room 2         4        NaN
# 30                Install FA Devices @ Function Room 2         5        NaN
# 31                  Install Flooring @ Function Room 2         6        NaN
# 27   Install Architectural Finishes & Trim  @ Funct...        10   8-Sep-15
# 34                  Install Millwork @ Function Room 2        15        NaN
# 35        Install Movable Partitions @ Function Room 2         5        NaN
# 39   Perform Plumbing & Sprinkler Finish Inspection...         1  14-Sep-15
# 23                       Final Paint @ Function Room 2         4        NaN
# 41                        Punchlist  @ Function Room 2         5   1-Oct-15
# 63                         Layout & Top Track @ Lounge         5        NaN
# 49   Frame & Core Board Risers/Stairs/Elevators @ L...        10        NaN
# 68                            Rough Duct Work @ Lounge        10        NaN
# 69                            Rough Sprinkler @ Lounge        10        NaN
# 50                     Frame Walls & Ceilings @ Lounge        10        NaN
# 61          Install Plumbing Frames & Crotons @ Lounge         5        NaN
# 66                                  Pull Wire @ Lounge        15        NaN
# 47                 Firestopping & Inspections @ Lounge         5        NaN
# 71           Sheetrock & Tape Walls & Celings @ Lounge        15        NaN
# 65                                Prime Paint @ Lounge         5        NaN
# 48                          Flash Patch Floor @ Lounge         5        NaN
# 59                Install Mechanical Finishes @ Lounge         2        NaN
# 62                    Install Sprinkler Heads @ Lounge         4        NaN
# 60                  Install Plumbing Finishes @ Lounge         2        NaN
# 56                Install Electrical Finishes @ Lounge         5        NaN
# 58                           Install Lighting @ Lounge         4        NaN
# 57                         Install FA Devices @ Lounge         5        NaN
# 72                   Tile Bar Surround Floors @ Lounge         5        NaN
# 53                       Install Ceiling Tile @ Lounge         5        NaN
# 52     Install Architectural Finishes & Trim  @ Lounge        10        NaN
# 51            Install & Protect Wood Flooring @ Lounge         5        NaN
# 70               Set Bar & Built in Furniture @ Lounge        15        NaN
# 55                              Install Doors @ Lounge         5        NaN
# 54                  Install Corridor Flooring @ Lounge         5        NaN
# 64   Perform Plumbing & Sprinkler Finish Inspection...         1        NaN
# 46                                Final Paint @ Lounge         4        NaN
# 67                                 Punchlist  @ Lounge         5        NaN
# 88             Layout & Top Track @ Pre-function Space         5  15-Oct-15
# 78              Install CMU Walls @ Pre-function Space        15  19-Oct-15
# 75   Frame & Core Board Risers/Stairs/Elevators @ P...        10  19-Oct-15
# 92                Rough Duct Work @ Pre-function Space        10  19-Oct-15
# 94        Rough Mechanical Piping @ Pre-function Space        10  19-Oct-15
# 95                 Rough Plumbing @ Pre-function Space        10  19-Oct-15
# 96                Rough Sprinkler @ Pre-function Space        10  19-Oct-15
# 93        Rough Electrical/FA/BMS @ Pre-function Space        10  10-Nov-15
# 76         Frame Walls & Ceilings @ Pre-function Space        10  19-Oct-15
# 74     Firestopping & Inspections @ Pre-function Space         5  19-Oct-15
# 90                    Prime Paint @ Pre-function Space         5        NaN
# 83    Install Mechanical Finishes @ Pre-function Space         2        NaN
# 87        Install Sprinkler Heads @ Pre-function Space         4        NaN
# 86      Install Plumbing Finishes @ Pre-function Space         2   1-Dec-15
# 79    Install Electrical Finishes @ Pre-function Space         5        NaN
# 82               Install Lighting @ Pre-function Space         4        NaN
# 80             Install FA Devices @ Pre-function Space         5   8-Dec-15
# 81               Install Flooring @ Pre-function Space         6        NaN
# 77   Install Architectural Finishes & Trim  @ Pre-f...        10  17-Dec-15
# 84               Install Millwork @ Pre-function Space        15        NaN
# 85     Install Movable Partitions @ Pre-function Space         5  15-Dec-15
# 89   Perform Plumbing & Sprinkler Finish Inspection...         1  21-Dec-15
# 73                    Final Paint @ Pre-function Space         4        NaN
# 91                     Punchlist  @ Pre-function Space         5   6-Jan-16
# 113              Layout & Top Track @ Public Restrooms         5  18-Jan-16
# 100  Frame & Core Board Risers/Stairs/Elevators @ P...        10   5-Feb-16
# 118                 Rough Duct Work @ Public Restrooms        10  26-Jan-16
# 120         Rough Mechanical Piping @ Public Restrooms        10  28-Jan-16
# 121                  Rough Plumbing @ Public Restrooms        10   1-Feb-16
# 122                 Rough Sprinkler @ Public Restrooms        10  21-Jan-16
# 119         Rough Electrical/FA/BMS @ Public Restrooms        10   3-Feb-16
# 101          Frame Walls & Ceilings @ Public Restrooms        10   8-Feb-16
# 111  Install Plumbing Frames & Crotons @ Public Res...         5  15-Feb-16
# 116                       Pull Wire @ Public Restrooms        15  17-Feb-16
# 98       Firestopping & Inspections @ Public Restrooms         5  23-Feb-16
# 123  Sheetrock & Tape Walls & Celings @ Public Rest...        15  26-Feb-16
# 115                     Prime Paint @ Public Restrooms         5        NaN
# 99                Flash Patch Floor @ Public Restrooms         5   2-Mar-16
# 109     Install Mechanical Finishes @ Public Restrooms         2  14-Apr-16
# 112         Install Sprinkler Heads @ Public Restrooms         4   4-Apr-16
# 110       Install Plumbing Finishes @ Public Restrooms         2   8-Apr-16
# 105     Install Electrical Finishes @ Public Restrooms         5        NaN
# 108                Install Lighting @ Public Restrooms         4  24-Mar-16
# 106              Install FA Devices @ Public Restrooms         5  28-Mar-16
# 103            Install Ceiling Tile @ Public Restrooms         5        NaN
# 107                Install Flooring @ Public Restrooms         6        NaN
# 102  Install Architectural Finishes & Trim  @ Publi...        10        NaN
# 104       Install Corridor Flooring @ Public Restrooms         5        NaN
# 114  Perform Plumbing & Sprinkler Finish Inspection...         1        NaN
# 97                      Final Paint @ Public Restrooms         4        NaN
# 117                      Punchlist  @ Public Restrooms         5        NaN
#
#         finish floor_id
# 15    5-Apr-16      FR1
# 5          NaN      FR1
# 2     3-May-16      FR1
# 19    7-Apr-16      FR1
# 21   27-Apr-16      FR1
# 22    7-Apr-16      FR1
# 20   27-Apr-16      FR1
# 3          NaN      FR1
# 1    29-Apr-16      FR1
# 17         NaN      FR1
# 10         NaN      FR1
# 14         NaN      FR1
# 13         NaN      FR1
# 6          NaN      FR1
# 9          NaN      FR1
# 7          NaN      FR1
# 8          NaN      FR1
# 4          NaN      FR1
# 11         NaN      FR1
# 12         NaN      FR1
# 16         NaN      FR1
# 0          NaN      FR1
# 18    7-Apr-16      FR1
# 38    8-Apr-16      FR2
# 28         NaN      FR2
# 25         NaN      FR2
# 42    8-Apr-16      FR2
# 44    3-May-16      FR2
# 45   29-Apr-16      FR2
# 43    2-May-16      FR2
# 26         NaN      FR2
# 24    5-May-16      FR2
# 40         NaN      FR2
# 33         NaN      FR2
# 37         NaN      FR2
# 36         NaN      FR2
# 29         NaN      FR2
# 32         NaN      FR2
# 30         NaN      FR2
# 31         NaN      FR2
# 27   10-Sep-15      FR2
# 34         NaN      FR2
# 35         NaN      FR2
# 39   17-Sep-15      FR2
# 23         NaN      FR2
# 41    2-Oct-15      FR2
# 63         NaN      LNG
# 49         NaN      LNG
# 68         NaN      LNG
# 69         NaN      LNG
# 50         NaN      LNG
# 61         NaN      LNG
# 66         NaN      LNG
# 47         NaN      LNG
# 71         NaN      LNG
# 65         NaN      LNG
# 48         NaN      LNG
# 59         NaN      LNG
# 62         NaN      LNG
# 60         NaN      LNG
# 56         NaN      LNG
# 58         NaN      LNG
# 57         NaN      LNG
# 72         NaN      LNG
# 53         NaN      LNG
# 52         NaN      LNG
# 51         NaN      LNG
# 70         NaN      LNG
# 55         NaN      LNG
# 54         NaN      LNG
# 64         NaN      LNG
# 46         NaN      LNG
# 67         NaN      LNG
# 88         NaN      PFS
# 78         NaN      PFS
# 75         NaN      PFS
# 92         NaN      PFS
# 94   31-Dec-15      PFS
# 95   30-Oct-15      PFS
# 96         NaN      PFS
# 93   11-Nov-15      PFS
# 76   30-Oct-15      PFS
# 74   18-Nov-15      PFS
# 90         NaN      PFS
# 83         NaN      PFS
# 87         NaN      PFS
# 86    7-Dec-15      PFS
# 79         NaN      PFS
# 82         NaN      PFS
# 80   14-Dec-15      PFS
# 81         NaN      PFS
# 77   18-Dec-15      PFS
# 84         NaN      PFS
# 85   16-Dec-15      PFS
# 89    5-Jan-16      PFS
# 73         NaN      PFS
# 91    7-Jan-16      PFS
# 113  20-Jan-16       PR
# 100   5-Feb-16       PR
# 118  27-Jan-16       PR
# 120   4-Feb-16       PR
# 121   2-Feb-16       PR
# 122  25-Jan-16       PR
# 119   3-Feb-16       PR
# 101  23-Mar-16       PR
# 111  16-Feb-16       PR
# 116  22-Feb-16       PR
# 98    1-Jun-17       PR
# 123   1-Mar-16       PR
# 115        NaN       PR
# 99    9-Mar-16       PR
# 109  25-May-16       PR
# 112   7-Apr-16       PR
# 110  13-Apr-16       PR
# 105        NaN       PR
# 108  25-Mar-16       PR
# 106   1-Apr-16       PR
# 103        NaN       PR
# 107        NaN       PR
# 102        NaN       PR
# 104        NaN       PR
# 114        NaN       PR
# 97         NaN       PR
# 117        NaN       PR

# %% [markdown]
# ## Relationships:
# 2. __Relationship/Logic Information :__ Relationship information consists of the realationship / logic information of a project. Each row is a relationship between two activities: a predecessor, and a successor. The columns that make up a relationship are:
#     1. __pred_id :__ This is the predecessor activity's ID
#
#     2. __succ_id :__ This is the successor activity's ID.
#
#     3. __pred_type :__ This tells the program the type of relationship between the two activities in the row. There are 4 types of relationships:<BR>
#        1: FS : the successor cannot _start_ until the predecessor _finishes_.<BR>
#        2: FF : the successor cannot _finish_ until the predecessor _finishes_.<BR>
#        3: SS : the successor cannot _start_ until the predecessor _starts_.<BR>
#        5: SF : the successor cannot _finish_ until the predecessor _starts_. (Considdered innapropriate and will not be used)
#
#     4. __pred_status :__ This tells the program the predecessor activity's status. If it has started, or if it has completed. All of the activities we will be making will have a status of "Not Started". This field is basically worthless, but the program requieres it when you are importing an activitiy.
#
#     5. __succ_status :__ same as pred_status, but for the successor.
#
#     6. __lag :__ This field is an integer represents how many days after when the pred_type field says an activity will start or finsh it will actually start or finish.

# %%
# This function creates a set of relationships from a list passed in by the user. It consists of two lists:
# 1. lstPred: the list of predecessor floors
# 2. lstSucc: the list of successor floors
# Since the schedule we are creating will be for a multi story building we need to create logic links 
# between floors. The two lists outline how to make these links.
def setRelationshipsList (strFileName, lstPred, lstSucc, strDropTag):
    # Read in the scheudle logic
    dfBaseLogic = pd.read_csv(strFileName ,dtype={'PredID': str, 'SucID': str})

    # We need to make sure that the PredID and SucID strings are the correct length
    # and that they should have leading zeros '0'.
    dfBaseLogic['SucID'] = dfBaseLogic['SucID'].str.zfill(3)
    dfBaseLogic['PredID'] = dfBaseLogic['PredID'].str.zfill(3)

    # Define the logic dataframe
    dfLogic = pd.DataFrame(columns=['pred_id', 'succ_id', 'pred_type', 'pred_status', \
                                    'succ_status', 'lag', 'remove'])
    
    # in the loop below the following line of code is important:
    # dfTemp = pd.DataFrame(dfBaseLogic['Sequence'].replace({0 : lstPred[int(i)], 1 : lstSucc[int(i)]}))
    # this line sets up the sequence column correctly. It sets it up using 2 values:
    #     0: if there is a 0 in the sequence row replace it with the corresponding item in lstPred
    #     1: if there is a 1 in the sequence row replace it with the corresponding item in lstSucc
    # This is important because the 0's go to activities on the same floor as this activity, and 
    # 1's go to activities on the successor floor as this activity.
    
    # this loop creates the dataframe that holds our relationship information
    for i in range(len(lstPred)):
        # assign the correct floor information in the sequence column.
        dfTemp = pd.DataFrame(dfBaseLogic['Sequence'].replace({0 : lstPred[int(i)], 1 : lstSucc[int(i)]}))
        # cache and format the relationship information
        dfNew = pd.DataFrame({
                'pred_id' : 'NA.' + lstPred[int(i)] + dfBaseLogic['PredID'], \
                'succ_id' : 'NA.' + dfTemp['Sequence'] + dfBaseLogic['SucID'], \
                'pred_type' : dfBaseLogic['Type'], \
                'pred_status' : strStatus, \
                'succ_status' : strStatus, \
                'lag' : dfBaseLogic['Lag'], \
                'remove' : dfTemp['Sequence']})
        
        # combine the new dataframe with the exiting one.
        dfLogic = pd.DataFrame(pd.concat([dfLogic,dfNew]))   
    
    # sort the dataframe by the 'pred_id' field
    dfLogic.sort_values('pred_id')
    # reset the index of the dataframe.
    dfLogic.reset_index(inplace=True, drop=True)

    # reset the index of the dataframe
    dfLogic.reset_index(inplace=True, drop=True)
    # drop relationships that will create loops when the schedule is calculated
    dfLogic.drop(dfLogic[dfLogic.succ_id == dfLogic.pred_id].index, inplace=True)
    # reset the index of the dataframe
    dfLogic.reset_index(inplace=True, drop=True)
    # drop relationships that are tagged to be removed
    dfLogic.drop(dfLogic[dfLogic.remove == 'DROP'].index, inplace=True)
    
    # reorder the dataframe and drop the "remove" row because we only needed it for filtering the final product
    dfLogic = dfLogic[['pred_id', 'succ_id', 'pred_type', 'pred_status', 'succ_status', 'lag']]
    
    # return the completed dataframe
    return dfLogic

# %%
# this function takes a template of relationships and duplicates them the specified number of times.
# unlike setRelationshipsList which uses lists, this one creates the relationships with a simple loop.
#    intStart: is the starting floor for our relationships
#    intFinish: is the finish floor for our relationships
def setRelationshipsRange(strFileName, intStart, intFinish, intBreakStart = 0, intBreakEnd = 0):
    # Read in the scheudle logic
    dfBaseLogic = pd.read_csv(strFileName ,dtype={'PredID': str, 'SucID': str})

    # We need to make sure that the PredID and SucID strings are the correct length
    # and that they should have leading zeros '0'.
    dfBaseLogic['SucID'] = dfBaseLogic['SucID'].str.zfill(3)
    dfBaseLogic['PredID'] = dfBaseLogic['PredID'].str.zfill(3)

    # Define my dataframe
    dfLogic = pd.DataFrame(columns=['pred_id', 'succ_id', 'pred_type', 'pred_status', \
        'succ_status', 'lag', 'PredFloor', 'SuccFloor'])

    # For each floor we want to create...
    for i in range(intStart, intFinish + 1):
        # cache and format the relationship information
        dfNew = pd.DataFrame({
            'pred_id' : 'NA.' + str(i).zfill(2) + dfBaseLogic['PredID'], \
            'succ_id' : 'NA.' + (i + dfBaseLogic['Sequence']).astype(str).str.zfill(2) + dfBaseLogic['SucID'], \
            'pred_type' : dfBaseLogic['Type'], \
            'pred_status' : strStatus, \
            'succ_status' : strStatus, \
            'lag' : dfBaseLogic['Lag'], \
            'PredFloor' : i, \
            'SuccFloor' : i + dfBaseLogic['Sequence']})
        
        # combine the new dataframe with the exiting one.
        dfLogic = pd.DataFrame(pd.concat([dfLogic,dfNew]))    

    # sort the dataframe by the 'pred_id' field
    dfLogic.sort_values('pred_id')
    
    # reset the index of the dataframe
    dfLogic.reset_index(inplace=True, drop=True)
    # drop rows with links to activities that are linked to intFinish (meaning one floor past the last floor)
    # it is VERY IMPORTANT that this is done AFTER you reset the index.
    dfLogic.drop(dfLogic[dfLogic.SuccFloor > intFinish].index, inplace=True)
    
    # reset the index of the dataframe
    dfLogic.reset_index(inplace=True, drop=True)
    
    # if the user specified a break start
    if intBreakStart > 0 :
        # drop impropper predecessor relationships to activities within the break area
        dfLogic.drop(dfLogic[(dfLogic.PredFloor >= intBreakStart) & (dfLogic.PredFloor < intBreakEnd)].index, inplace=True)
        # reset the index of the dataframe
        dfLogic.reset_index(inplace=True, drop=True)

        # drop impropper successor relationships to activities within the break area
        dfLogic.drop(dfLogic[(dfLogic.SuccFloor >= intBreakStart) & (dfLogic.SuccFloor < intBreakEnd)].index, inplace=True)
        # reset the index of the dataframe
        dfLogic.reset_index(inplace=True, drop=True)
    
    # drop loop creating relationships
    dfLogic.drop(dfLogic[dfLogic.succ_id == dfLogic.pred_id].index, inplace=True)
    
    # reorder the dataframe and drop PredFloor and SuccFloor because we only needed 
    # it for filtering the final product
    dfLogic = dfLogic[['pred_id', 'succ_id', 'pred_type', 'pred_status', 'succ_status', 'lag']]
    
    # return the completed dataframe
    return dfLogic

# %%
# This function removes relationships that point to activities that do not exist
def setCleanRelationships(dfLogicList, dfActivitiesList):
    
    # create a mask column that holds which rows in the pred_id column match the 
    # rows in the dfActivities id column
    dfLogicList['drop_mask'] = pd.Series(dfLogicList.pred_id.isin(dfActivitiesList.id))
    # reset the index
    dfLogicList.reset_index(inplace=True, drop=True)
    # Drop the rows outlined in the mask
    dfLogicList.drop(dfLogicList[~dfLogicList.drop_mask].index, inplace=True)
    # reset the index
    dfLogicList.reset_index(inplace=True, drop=True)

    dfLogicList['drop_mask'] = pd.Series(dfLogicList.succ_id.isin(dfActivitiesList.id))
    # reset the index
    dfLogicList.reset_index(inplace=True, drop=True)
    # Drop the rows outlined in the mask
    dfLogicList.drop(dfLogicList[~dfLogicList.drop_mask].index, inplace=True)
    # reset the index
    dfLogicList.reset_index(inplace=True, drop=True)
                               
    # drop the mask column
    dfLogicList.drop(['drop_mask'], axis=1)
    
    # retrun the cleaned dataframe
    return dfLogicList

# %%
# I need to create typical floors from the 13th floor to the 44th.
# I will do this by calling my floor creation function defined above. 
dfCreateLogic = setRelationshipsRange(strSourceLogic, 13, 44, 28, 30)

# remove rlationships to activities not in the activities list
dfCreateLogic = setCleanRelationships(dfCreateLogic, dfActivities)

# export the dataframe, without the index
dfCreateLogic.to_csv(strLogicFileOutput, index=False)

# review the dataframe we just exported
# In this run this should be empty
dfCreateLogic.head(5)
# Out:
# Empty DataFrame
# Columns: [pred_id, succ_id, pred_type, pred_status, succ_status, lag, drop_mask]
# Index: []

# %%
# Not all predecessor floors will have successor floors. For those activities I will
# add a drop code stored strDrop that will stipulate which rows to drop.
# assign the drop string
strDrop = 'DROP'

# I need to make relationships for floors 02 - 10. There is also a function room on 2 which
# Follows the initial work on 2. that is why you see '02' listed twice. Once for the links
# to the function room ('F3') and once for the 3rd floor ('03').
lstPredecessors = ['02', '02', 'F3', '03', '04', '05', '06', '07', '08', '09', '10']
lstSuccessors = ['F3', '03', strDrop, '04', '05', '06', '07', '08', '09', '10', strDrop]

# call the function to create the successors
dfLogic = setRelationshipsList(strSourceLogic, lstPredecessors, lstSuccessors, strDrop)

# remove rlationships to activities not in the activities list
dfLogic = setCleanRelationships(dfLogic, dfActivities)

# export the dataframe, without the index
dfLogic.to_csv(strLogicFileOutput, index=False)

# review the dataframe we just exported
# In this run this should be empty
dfLogic
# Out:
# Empty DataFrame
# Columns: [pred_id, succ_id, pred_type, pred_status, succ_status, lag, drop_mask]
# Index: []

# %%
# I need to make relationships for some other areas in a sister building. As you can see 
# They are not really tied together. Theses are just public spaces in the lower floors.
lstPredecessors = ['FR1', 'FR2', 'PFS', 'PR', 'LNG']
lstSuccessors = ['FR2', 'strDrop', 'PR', strDrop, strDrop]

# call the function to create the successors
dfLogic = setRelationshipsList(strSourceLogic, lstPredecessors, lstSuccessors, strDrop)

# remove rlationships to activities not in the activities list
dfLogic = setCleanRelationships(dfLogic, dfActivities)

# export the dataframe, without the index
dfLogic.to_csv(strLogicFileOutput, index=False)

# review the dataframe we just exported
# In this run there should be a bunch of relationships
dfLogic
# Out:
#        pred_id    succ_id pred_type  pred_status  succ_status lag  drop_mask
# 0    NA.FR1010  NA.FR1020        FS  Not Started  Not Started   0       True
# 1    NA.FR1017  NA.FR1070        FS  Not Started  Not Started   0       True
# 2    NA.FR1020  NA.FR1030        SS  Not Started  Not Started   2       True
# 3    NA.FR1030  NA.FR1040        SS  Not Started  Not Started   2       True
# 4    NA.FR1060  NA.FR1070        FS  Not Started  Not Started   0       True
# 5    NA.FR1130  NA.FR1140        FS  Not Started  Not Started   0       True
# 6    NA.FR1140  NA.FR1150        FS  Not Started  Not Started   0       True
# 7    NA.FR1150  NA.FR1160        FS  Not Started  Not Started   0       True
# 8    NA.FR1160  NA.FR1170        FS  Not Started  Not Started   0       True
# 9    NA.FR1173  NA.FR1170        FS  Not Started  Not Started   0       True
# 10   NA.FR1170  NA.FR1250        FS  Not Started  Not Started   0       True
# 11   NA.FR1250  NA.FR1290        FS  Not Started  Not Started   0       True
# 12   NA.FR1262  NA.FR1250        FS  Not Started  Not Started   0       True
# 13   NA.FR1280  NA.FR1300        FF  Not Started  Not Started   0       True
# 14   NA.FR1290  NA.FR1300        FF  Not Started  Not Started   0       True
# 15   NA.FR1300  NA.FR2300        FS  Not Started  Not Started   1       True
# 16   NA.FR1012  NA.FR1020        FS  Not Started  Not Started   0       True
# 17   NA.FR1020  NA.FR1030        FF  Not Started  Not Started   2       True
# 18   NA.FR1030  NA.FR1040        FF  Not Started  Not Started   2       True
# 19   NA.FR1060  NA.FR1100        FS  Not Started  Not Started   0       True
# 20   NA.FR1140  NA.FR1280        FS  Not Started  Not Started   0       True
# 21   NA.FR1150  NA.FR1280        FS  Not Started  Not Started   0       True
# 22   NA.FR1160  NA.FR1250        FS  Not Started  Not Started   0       True
# 23   NA.FR1173  NA.FR1250        FS  Not Started  Not Started   0       True
# 24   NA.FR1170  NA.FR1262        FS  Not Started  Not Started   0       True
# 25   NA.FR1230  NA.FR1257        FS  Not Started  Not Started   0       True
# 26   NA.FR1250  NA.FR1230        FS  Not Started  Not Started   0       True
# 27   NA.FR1010  NA.FR1012        FS  Not Started  Not Started   0       True
# 28   NA.FR1040  NA.FR1017        SS  Not Started  Not Started   5       True
# 29   NA.FR1120  NA.FR1130        FS  Not Started  Not Started   0       True
# 30   NA.FR1160  NA.FR1173        FS  Not Started  Not Started   0       True
# 31   NA.FR1173  NA.FR1262        FS  Not Started  Not Started   0       True
# 32   NA.FR1010  NA.FR2010        FS  Not Started  Not Started   0       True
# 33   NA.FR1012  NA.FR2012        FS  Not Started  Not Started   0       True
# 34   NA.FR1017  NA.FR2070        FS  Not Started  Not Started   0       True
# 35   NA.FR1020  NA.FR2020        FS  Not Started  Not Started   0       True
# 36   NA.FR1030  NA.FR2030        FS  Not Started  Not Started   0       True
# 37   NA.FR1040  NA.FR2040        FS  Not Started  Not Started   0       True
# 38   NA.FR1060  NA.FR2060        FS  Not Started  Not Started   0       True
# 39   NA.FR1070  NA.FR2070        FS  Not Started  Not Started   0       True
# 40   NA.FR1100  NA.FR2100        FS  Not Started  Not Started   0       True
# 41   NA.FR1120  NA.FR1160        FS  Not Started  Not Started   0       True
# 42   NA.FR1140  NA.FR2140        FS  Not Started  Not Started   0       True
# 43   NA.FR1150  NA.FR2150        FS  Not Started  Not Started   0       True
# 44   NA.FR1160  NA.FR2160        FS  Not Started  Not Started   0       True
# 45   NA.FR1170  NA.FR2170        FS  Not Started  Not Started   0       True
# 46   NA.FR1230  NA.FR2230        FS  Not Started  Not Started   0       True
# 47   NA.FR1250  NA.FR2250        SS  Not Started  Not Started   5       True
# 48   NA.FR2010  NA.FR2020        FS  Not Started  Not Started   0       True
# 49   NA.FR2017  NA.FR2070        FS  Not Started  Not Started   0       True
# 50   NA.FR2020  NA.FR2030        SS  Not Started  Not Started   2       True
# 51   NA.FR2030  NA.FR2040        SS  Not Started  Not Started   2       True
# 52   NA.FR2060  NA.FR2070        FS  Not Started  Not Started   0       True
# 53   NA.FR2130  NA.FR2140        FS  Not Started  Not Started   0       True
# 54   NA.FR2140  NA.FR2150        FS  Not Started  Not Started   0       True
# 55   NA.FR2150  NA.FR2160        FS  Not Started  Not Started   0       True
# 56   NA.FR2160  NA.FR2170        FS  Not Started  Not Started   0       True
# 57   NA.FR2173  NA.FR2170        FS  Not Started  Not Started   0       True
# 58   NA.FR2170  NA.FR2250        FS  Not Started  Not Started   0       True
# 59   NA.FR2250  NA.FR2290        FS  Not Started  Not Started   0       True
# 60   NA.FR2262  NA.FR2250        FS  Not Started  Not Started   0       True
# 61   NA.FR2280  NA.FR2300        FF  Not Started  Not Started   0       True
# 62   NA.FR2290  NA.FR2300        FF  Not Started  Not Started   0       True
# 63   NA.FR2012  NA.FR2020        FS  Not Started  Not Started   0       True
# 64   NA.FR2020  NA.FR2030        FF  Not Started  Not Started   2       True
# 65   NA.FR2030  NA.FR2040        FF  Not Started  Not Started   2       True
# 66   NA.FR2060  NA.FR2100        FS  Not Started  Not Started   0       True
# 67   NA.FR2140  NA.FR2280        FS  Not Started  Not Started   0       True
# 68   NA.FR2150  NA.FR2280        FS  Not Started  Not Started   0       True
# 69   NA.FR2160  NA.FR2250        FS  Not Started  Not Started   0       True
# 70   NA.FR2173  NA.FR2250        FS  Not Started  Not Started   0       True
# 71   NA.FR2170  NA.FR2262        FS  Not Started  Not Started   0       True
# 72   NA.FR2230  NA.FR2257        FS  Not Started  Not Started   0       True
# 73   NA.FR2250  NA.FR2230        FS  Not Started  Not Started   0       True
# 74   NA.FR2010  NA.FR2012        FS  Not Started  Not Started   0       True
# 75   NA.FR2040  NA.FR2017        SS  Not Started  Not Started   5       True
# 76   NA.FR2120  NA.FR2130        FS  Not Started  Not Started   0       True
# 77   NA.FR2160  NA.FR2173        FS  Not Started  Not Started   0       True
# 78   NA.FR2173  NA.FR2262        FS  Not Started  Not Started   0       True
# 79   NA.FR2120  NA.FR2160        FS  Not Started  Not Started   0       True
# 80   NA.PFS010  NA.PFS020        FS  Not Started  Not Started   0       True
# 81   NA.PFS017  NA.PFS070        FS  Not Started  Not Started   0       True
# 82   NA.PFS020  NA.PFS030        SS  Not Started  Not Started   2       True
# 83   NA.PFS030  NA.PFS040        SS  Not Started  Not Started   2       True
# 84   NA.PFS040  NA.PFS050        SS  Not Started  Not Started   2       True
# 85   NA.PFS050  NA.PFS060        SS  Not Started  Not Started   2       True
# 86   NA.PFS060  NA.PFS070        FS  Not Started  Not Started   0       True
# 87   NA.PFS130  NA.PFS140        FS  Not Started  Not Started   0       True
# 88   NA.PFS140  NA.PFS150        FS  Not Started  Not Started   0       True
# 89   NA.PFS150  NA.PFS160        FS  Not Started  Not Started   0       True
# 90   NA.PFS160  NA.PFS170        FS  Not Started  Not Started   0       True
# 91   NA.PFS173  NA.PFS170        FS  Not Started  Not Started   0       True
# 92   NA.PFS170  NA.PFS250        FS  Not Started  Not Started   0       True
# 93   NA.PFS250  NA.PFS290        FS  Not Started  Not Started   0       True
# 94   NA.PFS262  NA.PFS250        FS  Not Started  Not Started   0       True
# 95   NA.PFS280  NA.PFS300        FF  Not Started  Not Started   0       True
# 96   NA.PFS290  NA.PFS300        FF  Not Started  Not Started   0       True
# 97   NA.PFS300   NA.PR300        FS  Not Started  Not Started   1       True
# 98   NA.PFS012  NA.PFS020        FS  Not Started  Not Started   0       True
# 99   NA.PFS020  NA.PFS030        FF  Not Started  Not Started   2       True
# 100  NA.PFS030  NA.PFS040        FF  Not Started  Not Started   2       True
# 101  NA.PFS040  NA.PFS050        FF  Not Started  Not Started   2       True
# 102  NA.PFS050  NA.PFS060        FF  Not Started  Not Started   2       True
# 103  NA.PFS060  NA.PFS100        FS  Not Started  Not Started   0       True
# 104  NA.PFS140  NA.PFS280        FS  Not Started  Not Started   0       True
# 105  NA.PFS150  NA.PFS280        FS  Not Started  Not Started   0       True
# 106  NA.PFS160  NA.PFS250        FS  Not Started  Not Started   0       True
# 107  NA.PFS173  NA.PFS250        FS  Not Started  Not Started   0       True
# 108  NA.PFS170  NA.PFS262        FS  Not Started  Not Started   0       True
# 109  NA.PFS230  NA.PFS257        FS  Not Started  Not Started   0       True
# 110  NA.PFS250  NA.PFS230        FS  Not Started  Not Started   0       True
# 111  NA.PFS010  NA.PFS012        FS  Not Started  Not Started   0       True
# 112  NA.PFS040  NA.PFS017        SS  Not Started  Not Started   5       True
# 113  NA.PFS120  NA.PFS130        FS  Not Started  Not Started   0       True
# 114  NA.PFS160  NA.PFS173        FS  Not Started  Not Started   0       True
# 115  NA.PFS173  NA.PFS262        FS  Not Started  Not Started   0       True
# 116  NA.PFS010   NA.PR010        FS  Not Started  Not Started   0       True
# 117  NA.PFS017   NA.PR070        FS  Not Started  Not Started   0       True
# 118  NA.PFS020   NA.PR020        FS  Not Started  Not Started   0       True
# 119  NA.PFS030   NA.PR030        FS  Not Started  Not Started   0       True
# 120  NA.PFS040   NA.PR040        FS  Not Started  Not Started   0       True
# 121  NA.PFS050   NA.PR050        FS  Not Started  Not Started   0       True
# 122  NA.PFS060   NA.PR060        FS  Not Started  Not Started   0       True
# 123  NA.PFS070   NA.PR070        FS  Not Started  Not Started   0       True
# 124  NA.PFS100   NA.PR100        FS  Not Started  Not Started   0       True
# 125  NA.PFS120  NA.PFS160        FS  Not Started  Not Started   0       True
# 126  NA.PFS140   NA.PR140        FS  Not Started  Not Started   0       True
# 127  NA.PFS150   NA.PR150        FS  Not Started  Not Started   0       True
# 128  NA.PFS160   NA.PR160        FS  Not Started  Not Started   0       True
# 129  NA.PFS170   NA.PR170        FS  Not Started  Not Started   0       True
# 130  NA.PFS230   NA.PR230        FS  Not Started  Not Started   0       True
# 131  NA.PFS250   NA.PR250        SS  Not Started  Not Started   5       True
# 132   NA.PR010   NA.PR020        FS  Not Started  Not Started   0       True
# 133   NA.PR017   NA.PR070        FS  Not Started  Not Started   0       True
# 134   NA.PR020   NA.PR030        SS  Not Started  Not Started   2       True
# 135   NA.PR030   NA.PR040        SS  Not Started  Not Started   2       True
# 136   NA.PR040   NA.PR050        SS  Not Started  Not Started   2       True
# 137   NA.PR050   NA.PR060        SS  Not Started  Not Started   2       True
# 138   NA.PR060   NA.PR070        FS  Not Started  Not Started   0       True
# 139   NA.PR070   NA.PR110        FS  Not Started  Not Started   0       True
# 140   NA.PR080   NA.PR110        FS  Not Started  Not Started   0       True
# 141   NA.PR090   NA.PR160        FS  Not Started  Not Started   0       True
# 142   NA.PR100   NA.PR110        FS  Not Started  Not Started   0       True
# 143   NA.PR110   NA.PR120        FS  Not Started  Not Started   0       True
# 144   NA.PR130   NA.PR140        FS  Not Started  Not Started   0       True
# 145   NA.PR140   NA.PR150        FS  Not Started  Not Started   0       True
# 146   NA.PR150   NA.PR160        FS  Not Started  Not Started   0       True
# 147   NA.PR160   NA.PR170        FS  Not Started  Not Started   0       True
# 148   NA.PR173   NA.PR170        FS  Not Started  Not Started   0       True
# 149   NA.PR170   NA.PR250        FS  Not Started  Not Started   0       True
# 150   NA.PR185   NA.PR290        FS  Not Started  Not Started   0       True
# 151   NA.PR250   NA.PR290        FS  Not Started  Not Started   0       True
# 152   NA.PR270   NA.PR290        FS  Not Started  Not Started   0       True
# 153   NA.PR280   NA.PR300        FF  Not Started  Not Started   0       True
# 154   NA.PR290   NA.PR300        FF  Not Started  Not Started   0       True
# 155   NA.PR010   NA.PR080        FS  Not Started  Not Started   0       True
# 156   NA.PR020   NA.PR030        FF  Not Started  Not Started   2       True
# 157   NA.PR030   NA.PR040        FF  Not Started  Not Started   2       True
# 158   NA.PR040   NA.PR050        FF  Not Started  Not Started   2       True
# 159   NA.PR050   NA.PR060        FF  Not Started  Not Started   2       True
# 160   NA.PR060   NA.PR100        FS  Not Started  Not Started   0       True
# 161   NA.PR070   NA.PR080        FS  Not Started  Not Started   0       True
# 162   NA.PR090   NA.PR170        FS  Not Started  Not Started   0       True
# 163   NA.PR110   NA.PR123        FS  Not Started  Not Started   0       True
# 164   NA.PR123   NA.PR230        FS  Not Started  Not Started   0       True
# 165   NA.PR140   NA.PR280        FS  Not Started  Not Started   0       True
# 166   NA.PR150   NA.PR280        FS  Not Started  Not Started   0       True
# 167   NA.PR160   NA.PR250        FS  Not Started  Not Started   0       True
# 168   NA.PR173   NA.PR250        FS  Not Started  Not Started   0       True
# 169   NA.PR250   NA.PR230        FS  Not Started  Not Started   0       True
# 170   NA.PR040   NA.PR017        SS  Not Started  Not Started   5       True
# 171   NA.PR060   NA.PR090        FS  Not Started  Not Started   0       True
# 172   NA.PR120   NA.PR130        FS  Not Started  Not Started   0       True
# 173   NA.PR160   NA.PR173        FS  Not Started  Not Started   0       True
# 174   NA.PR170   NA.PR185        FS  Not Started  Not Started   0       True
# 175   NA.PR120   NA.PR160        FS  Not Started  Not Started   0       True
# 176  NA.LNG010  NA.LNG020        FS  Not Started  Not Started   0       True
# 177  NA.LNG017  NA.LNG070        FS  Not Started  Not Started   0       True
# 178  NA.LNG070  NA.LNG110        FS  Not Started  Not Started   0       True
# 179  NA.LNG080  NA.LNG110        FS  Not Started  Not Started   0       True
# 180  NA.LNG090  NA.LNG160        FS  Not Started  Not Started   0       True
# 181  NA.LNG100  NA.LNG110        FS  Not Started  Not Started   0       True
# 182  NA.LNG110  NA.LNG120        FS  Not Started  Not Started   0       True
# 183  NA.LNG130  NA.LNG140        FS  Not Started  Not Started   0       True
# 184  NA.LNG140  NA.LNG150        FS  Not Started  Not Started   0       True
# 185  NA.LNG150  NA.LNG160        FS  Not Started  Not Started   0       True
# 186  NA.LNG160  NA.LNG170        FS  Not Started  Not Started   0       True
# 187  NA.LNG173  NA.LNG170        FS  Not Started  Not Started   0       True
# 188  NA.LNG170  NA.LNG250        FS  Not Started  Not Started   0       True
# 189  NA.LNG185  NA.LNG290        FS  Not Started  Not Started   0       True
# 190  NA.LNG253  NA.LNG257        FS  Not Started  Not Started   0       True
# 191  NA.LNG250  NA.LNG290        FS  Not Started  Not Started   0       True
# 192  NA.LNG257  NA.LNG260        FS  Not Started  Not Started   0       True
# 193  NA.LNG260  NA.LNG290        FS  Not Started  Not Started   0       True
# 194  NA.LNG270  NA.LNG290        FS  Not Started  Not Started   0       True
# 195  NA.LNG280  NA.LNG300        FF  Not Started  Not Started   0       True
# 196  NA.LNG290  NA.LNG300        FF  Not Started  Not Started   0       True
# 197  NA.LNG010  NA.LNG080        FS  Not Started  Not Started   0       True
# 198  NA.LNG070  NA.LNG080        FS  Not Started  Not Started   0       True
# 199  NA.LNG090  NA.LNG170        FS  Not Started  Not Started   0       True
# 200  NA.LNG110  NA.LNG123        FS  Not Started  Not Started   0       True
# 201  NA.LNG120  NA.LNG177        FS  Not Started  Not Started   0       True
# 202  NA.LNG140  NA.LNG280        FS  Not Started  Not Started   0       True
# 203  NA.LNG150  NA.LNG280        FS  Not Started  Not Started   0       True
# 204  NA.LNG160  NA.LNG250        FS  Not Started  Not Started   0       True
# 205  NA.LNG173  NA.LNG250        FS  Not Started  Not Started   0       True
# 206  NA.LNG253  NA.LNG270        FS  Not Started  Not Started   0       True
# 207  NA.LNG260  NA.LNG270        FS  Not Started  Not Started   0       True
# 208  NA.LNG120  NA.LNG130        FS  Not Started  Not Started   0       True
# 209  NA.LNG160  NA.LNG173        FS  Not Started  Not Started   0       True
# 210  NA.LNG170  NA.LNG185        FS  Not Started  Not Started   0       True
# 211  NA.LNG120  NA.LNG160        FS  Not Started  Not Started   0       True
